# %% [markdown]
# ## 1. La legge dei grandi numeri
#
# La legge dei grandi numeri è un teorema fondamentale della teoria della probabilità che indica che se ripetiamo molte volte (tendendo all'infinito) lo stesso esperimento, la frequenza di un certo evento tende ad essere costante.
#
# Vale a dire, **la legge dei grandi numeri indica che se lo stesso test viene eseguito ripetutamente (ad esempio, lancio di una moneta), la frequenza con cui si ripeterà un determinato evento (testa/croce) si avvicinerà a una costante. Questa a sua volta sarà la probabilità che questo evento si verifichi.**
#
# Fonte: https://it.economy-pedia.com/11038376-law-of-the-big-numbers
#
# - Scrivere una funzione che simula il lancio di una moneta per N volte e restituisce la frequenza % di volte che è uscita testa.
# - Calcolare la frequenza % con la grandezze del campione (numero di lanci) che varia 100 volte da 10 a 20000. Ottengo quindi 100 valori.
# - Fare il plot del Numero medio di teste (y) rispetto alla grandezza del campione (x)

# %%
import numpy as np
import matplotlib.pyplot as plt

def teste(n_lanci):
    lanci = [np.random.randint(0, 1+1) for i in range(n_lanci)]
    n_teste = sum(lanci)
    frequenza = (n_teste/n_lanci)*100
    print(f'In {n_lanci} abbiamo ottenuto {n_teste} teste, quindi con frequenza: {frequenza}%')

teste(100)
# Out:
# In 100 abbiamo ottenuto 49 teste, quindi con frequenza: 49.0%

# %%
grandezza_campione = np.arange(10, 20000, 100)
lista_frequenze = [(sum(np.random.randint(0, 1+1) for i in range(size))/size) for size in grandezza_campione]

lista_frequenze
# Out:
# [np.float64(1.0),
#  np.float64(0.4636363636363636),
#  np.float64(0.5238095238095238),
#  np.float64(0.5161290322580645),
#  np.float64(0.4609756097560976),
#  np.float64(0.5078431372549019),
#  np.float64(0.49836065573770494),
#  np.float64(0.4971830985915493),
#  np.float64(0.5098765432098765),
#  np.float64(0.4978021978021978),
#  np.float64(0.504950495049505),
#  np.float64(0.5099099099099099),
#  np.float64(0.4884297520661157),
#  np.float64(0.5068702290076336),
#  np.float64(0.5049645390070922),
#  np.float64(0.4986754966887417),
#  np.float64(0.5037267080745341),
#  np.float64(0.4988304093567251),
#  np.float64(0.494475138121547),
#  np.float64(0.4973821989528796),
#  np.float64(0.5303482587064676),
#  np.float64(0.49715639810426543),
#  np.float64(0.4819004524886878),
#  np.float64(0.49826839826839825),
#  np.float64(0.520746887966805),
#  np.float64(0.5159362549800797),
#  np.float64(0.5007662835249043),
#  np.float64(0.4992619926199262),
#  np.float64(0.5149466192170818),
#  np.float64(0.5017182130584192),
#  np.float64(0.4926910299003322),
#  np.float64(0.4980707395498392),
#  np.float64(0.4996884735202492),
#  np.float64(0.49244712990936557),
#  np.float64(0.5043988269794721),
#  np.float64(0.4985754985754986),
#  np.float64(0.503601108033241),
#  np.float64(0.493800539083558),
#  np.float64(0.5055118110236221),
#  np.float64(0.50076726342711),
#  np.float64(0.5064837905236907),
#  np.float64(0.5041362530413626),
#  np.float64(0.5066508313539192),
#  np.float64(0.4976798143851508),
#  np.float64(0.5052154195011338),
#  np.float64(0.5057532172596518),
#  np.float64(0.5009015777610819),
#  np.float64(0.4947054436987323),
#  np.float64(0.500740192450037),
#  np.float64(0.49529757531227037),
#  np.float64(0.5010940919037199),
#  np.float64(0.5070238957277335),
#  np.float64(0.5001437814521926),
#  np.float64(0.5017844396859387),
#  np.float64(0.502338766832034),
#  np.float64(0.5036593947923997),
#  np.float64(0.5004891684136967),
#  np.float64(0.4958362248438584),
#  np.float64(0.5024810475534114),
#  np.float64(0.4994524298425736),
#  np.float64(0.5083616587355541),
#  np.float64(0.5024983119513842),
#  np.float64(0.4947686116700201),
#  np.float64(0.49613590939373753),
#  np.float64(0.49907346128391794),
#  np.float64(0.5025641025641026),
#  np.float64(0.5011103853690398),
#  np.float64(0.4961713173264114),
#  np.float64(0.5010960670535138),
#  np.float64(0.4988468930172966),
#  np.float64(0.49732654360280076),
#  np.float64(0.4973434535104364),
#  np.float64(0.5030169704588309),
#  np.float64(0.5007495315427858),
#  np.float64(0.5047175667287399),
#  np.float64(0.5030845157310302),
#  np.float64(0.5057020232985898),
#  np.float64(0.5042656916514321),
#  np.float64(0.4997577225923683),
#  np.float64(0.5022275737507526),
#  np.float64(0.49766606822262116),
#  np.float64(0.4939321832242713),
#  np.float64(0.49905381431105855),
#  np.float64(0.49570840681951794),
#  np.float64(0.49830508474576274),
#  np.float64(0.49570017431725744),
#  np.float64(0.4966493356441363),
#  np.float64(0.4973578403216542),
#  np.float64(0.5007995431182182),
#  np.float64(0.5051107325383305),
#  np.float64(0.4967250141163185),
#  np.float64(0.5022459292532285),
#  np.float64(0.4945840312674484),
#  np.float64(0.5026096612992782),
#  np.float64(0.5056322473771397),
#  np.float64(0.49758374519494786),
#  np.float64(0.5052976515565265),
#  np.float64(0.49760999456816946),
#  np.float64(0.5011345218800648),
#  np.float64(0.5053197205803331),
#  np.float64(0.4974879743452699),
#  np.float64(0.4932482721956406),
#  np.float64(0.5020095187731359),
#  np.float64(0.49442398737506577),
#  np.float64(0.5014128728414443),
#  np.float64(0.5040083289953149),
#  np.float64(0.5018643190056965),
#  np.float64(0.5020607934054611),
#  np.float64(0.49841107124551515),
#  np.float64(0.4988271290158083),
#  np.float64(0.5028411973617453),
#  np.float64(0.49384149419485107),
#  np.float64(0.4949271722752386)]

# %%
plt.figure(figsize=(12,6))
plt.axhline(y = 0.5, color = 'orange', linewidth = 5)
plt.plot(grandezza_campione, lista_frequenze, color = 'skyblue')
plt.title('Numero medio di teste rispetto alla grandezza del campione')
plt.xlabel('Grandezza campione')
plt.ylabel('Numero medio teste')
plt.show()

# %% [markdown]
# ## 2. Analisi del Dataset Titanic
# - Quante righe e colonne ha il dataset?
# - Controlla quanti valori mancanti ci sono per colonna
# - Riempi i valori mancanti nella colonna 'Embarked' con il valore più frequente
# - Rimuovi le righe dove il valore di 'Age' è mancante
# - Controlla se ci sono righe duplicate
# - Calcola l'età media dei passeggeri per ogni classe (`Pclass`), se ci sono valori mancanti di età riempili con il valore medio
# - Visualizza la distribuzione dell'età per classe
# - Visualizza la distribuzione dell'età per classe dividendo e mmostrando insieme i dati di uomini e donne

# %%
# 📦 Caricamento del dataset
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
len(df.columns) #numero colonne
len(df) #numero righe

for col in df.columns: #valori mancanti per colonna
    mancanti = len(df) - sum(df[col].notna())
    print(f"Colonna {col}: {mancanti} valori mancanti\n")

moda_embarked = df["Embarked"].mode()[0] #riempio i valori NA con il + frequente
df['Embarked'].fillna(moda_embarked, inplace=True) 

df = df[df['Age'].notna()] #rimuovo righe con valori 'Age' mancanti

print("\nRighe duplicate: ", df.duplicated().sum()) #controllo se ci sono righe duplicate

mean_ages = df.groupby('Pclass')['Age'].mean() #calcolo età media per classe di passeggeri (già riempiti i valori mancanti)
print(f"Età media per classe di passeggeri: {mean_ages}")

sns.histplot(data=df, x='Age', hue='Pclass', kde=True) 
plt.title("Distribuzione dell'età per classe")
plt.show()

sns.histplot(data=df, x='Age', hue='Sex', kde=True)
plt.title("Distribuzione dell'età per classe dividendo uomini e donne")
plt.show()
# Out:
# Colonna PassengerId: 0 valori mancanti
#
# Colonna Survived: 0 valori mancanti
#
# Colonna Pclass: 0 valori mancanti
#
# Colonna Name: 0 valori mancanti
#
# Colonna Sex: 0 valori mancanti
#
# Colonna Age: 0 valori mancanti
#
# Colonna SibSp: 0 valori mancanti
#
# Colonna Parch: 0 valori mancanti
#
# Colonna Ticket: 0 valori mancanti
#
# Colonna Fare: 0 valori mancanti
#
# Colonna Cabin: 529 valori mancanti
#
# Colonna Embarked: 0 valori mancanti
#
#
# Righe duplicate:  0
# Età media per classe di passeggeri: Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64
# C:\Users\franc\AppData\Local\Temp\ipykernel_31112\2774426609.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Embarked'].fillna(moda_embarked, inplace=True)

# %% [markdown]
# ## 3. Analisi del Dataset Iris
#
# - Esplora la distribuzione delle specie (conta quanti campioni ci sono per specie)
# - Calcola la lunghezza e la larghezza media dei petali per specie
# - Visualizza le dimensioni dei petali per specie (scatterplot)
# - Crea una nuova colonna per l'area del petalo e analizzala
# - Grafico della distribuzione dell'area del petalo per specie (boxplot)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"
df = pd.read_csv(url)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#primo punto
print(f"Distribuzione delle specie: {df['species'].value_counts()}")

#secondo punto
medie_petali_per_specie = df.groupby('species')[['petal_length', 'petal_width']].mean()

#terzo punto
colors = {'setosa': 'red', 'versicolor': 'green', 'virginica': 'blue'}
plt.figure(figsize=(10,6))
for specie in df['species'].unique():
    dati_specie = df[df['species'] == specie]
    plt.scatter(dati_specie['petal_width'], dati_specie['petal_length'], color=colors[specie], label=specie)
plt.title('Dimensioni dei petali per specie')
plt.xlabel('Larghezza petali per specie')
plt.ylabel('Lunghezza petali per specie')
plt.grid(True)
plt.show()

#quarto punto
df['petal_area'] = (df['petal_length'].astype(int)*df['petal_width'].astype(int))

#quinto punto
sns.boxplot(data=df, x='species', y='petal_area')
plt.title("Distribuzione dell'area del petalo per specie")
plt.show()
# Out:
# Distribuzione delle specie: species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64
